# %%
try:
    from faker import Faker
except:
   # !pip install faker 
   from faker import Faker
    
try:
    import psycopg2 
except:
    # !pip install psycopg2-binary 
    import psycopg2
    
try:
    from sqlalchemy import create_engine
except:
    # !pip install sqlalchemy
    from sqlalchemy import create_engine
    
    
try:
    import pandas as pd 
except:
    # !pip install pandas
    import pandas as pd 
     
try:
    import matplotlib 
except:
    # !pip install matplotlib
    import matplotlib

try:
    import sklearn 
except:
    # !pip install sklearn
    import sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faker
#   Downloading Faker-13.12.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 8.5 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.12.1
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
import pandas as pd 
URL='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv'
UID_ISO_FIPS_LookUp_Table=pd.read_csv(URL)
UID_ISO_FIPS_LookUp_Table.head(10)
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State       Country_Region  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN          Afghanistan
# 1    8   AL  ALB    8.0   NaN    NaN            NaN              Albania
# 2   10   AQ  ATA   10.0   NaN    NaN            NaN           Antarctica
# 3   12   DZ  DZA   12.0   NaN    NaN            NaN              Algeria
# 4   20   AD  AND   20.0   NaN    NaN            NaN              Andorra
# 5   24   AO  AGO   24.0   NaN    NaN            NaN               Angola
# 6   28   AG  ATG   28.0   NaN    NaN            NaN  Antigua and Barbuda
# 7   32   AR  ARG   32.0   NaN    NaN            NaN            Argentina
# 8   51   AM  ARM   51.0   NaN    NaN            NaN              Armenia
# 9   40   AT  AUT   40.0   NaN    NaN            NaN              Austria
#
#         Lat      Long_         Combined_Key  Population
# 0  33.93911  67.709953          Afghanistan  38928341.0
# 1  41.15330  20.168300              Albania   2877800.0
# 2 -71.94990  23.347000           Antarctica         NaN
# 3  28.03390   1.659600              Algeria  43851043.0
# 4  42.50630   1.521800              Andorra     77265.0
# 5 -11.20270  17.873900               Angola  32866268.0
# 6  17.06080 -61.796400  Antigua and Barbuda     97928.0
# 7 -38.41610 -63.616700            Argentina  45195777.0
# 8  40.06910  45.038200              Armenia   2963234.0
# 9  47.51620  14.550100              Austria   9006400.0

# %%
import pandas as pd 
Day='01-06-2022'
Country_Region='United Kingdom'
URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
DF_day=pd.read_csv(URL_Day)
DF_day.head(3)
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2022-01-07 04:22:09  33.93911
# 1   NaN    NaN            NaN        Albania  2022-01-07 04:22:09  41.15330
# 2   NaN    NaN            NaN        Algeria  2022-01-07 04:22:09  28.03390
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     158275    7367        NaN     NaN  Afghanistan
# 1  20.168300     213257    3228        NaN     NaN      Albania
# 2   1.659600     220825    6318        NaN     NaN      Algeria
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     406.580388             4.654557
# 1    7410.417680             1.513667
# 2     503.579812             2.861089

# %%
import pandas as pd 
Day='06-01-2022'
URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
DF_day=pd.read_csv(URL_Day)
DF_day.head(3)
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2022-06-02 05:20:39  33.93911
# 1   NaN    NaN            NaN        Albania  2022-06-02 05:20:39  41.15330
# 2   NaN    NaN            NaN        Algeria  2022-06-02 05:20:39  28.03390
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     180419    7707        NaN     NaN  Afghanistan
# 1  20.168300     276221    3497        NaN     NaN      Albania
# 2   1.659600     265887    6875        NaN     NaN      Algeria
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     463.464395             4.271723
# 1    9598.339009             1.266015
# 2     606.341336             2.585685

# %%
File1='time_series_covid19_confirmed_global'
File2='time_series_covid19_confirmed_United Kingdom'
File3='time_series_covid19_deaths_global'
File4='time_series_covid19_deaths_United Kingdom'
File5='time_series_covid19_recovered_global'
URL_TimeSeries=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/{File1}.csv'
DF_TimeSeries=pd.read_csv(URL_TimeSeries)
DF_TimeSeries.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/30/22  \
# 0        0        0        0        0        0        0  ...   180259
# 1        0        0        0        0        0        0  ...   276101
# 2        0        0        0        0        0        0  ...   265877
# 3        0        0        0        0        0        0  ...    42894
# 4        0        0        0        0        0        0  ...    99761
# 5        0        0        0        0        0        0  ...       11
# 6        0        0        0        0        0        0  ...     8163
# 7        0        0        0        0        0        0  ...  9230573
# 8        0        0        0        0        0        0  ...   422963
# 9        0        0        0        0        0        0  ...   131938
#
#    5/31/22   6/1/22   6/2/22   6/3/22   6/4/22   6/5/22   6/6/22   6/7/22  \
# 0   180347   180419   180520   180584   180615   180615   180688   180741
# 1   276101   276221   276221   276310   276342   276401   276415   276468
# 2   265884   265887   265889   265889   265889   265897   265900   265904
# 3    42894    42894    42894    43067    43067    43067    43067    43067
# 4    99761    99761    99761    99761    99761    99761    99761    99761
# 5       11       11       11       11       11       11       11       11
# 6     8253     8253     8295     8295     8378     8378     8378     8378
# 7  9230573  9230573  9230573  9230573  9230573  9276618  9276618  9276618
# 8   422963   422963   422963   422963   422963   422963   423006   423006
# 9   132735   133582   134286   134286   134286   134286   136860   137664
#
#     6/8/22
# 0   180784
# 1   276518
# 2   265909
# 3    43224
# 4    99761
# 5       11
# 6     8378
# 7  9276618
# 8   423006
# 9   138407
#
# [10 rows x 873 columns]

# %%
# Get all daily data for UK directly from github repo up to now
import pandas as pd 
Day='01-01-2021'
URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
DF_day=pd.read_csv(URL_Day)
DF_day['Day']=Day
cond=(DF_day.Country_Region=='United Kingdom')
Selec_columns=['Day','Country_Region', 'Last_Update',
       'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
       'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']
DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
DF_i
# Out:
#            Day  Country_Region          Last_Update        Lat      Long_  \
# 0   01-01-2021  United Kingdom  2021-01-02 05:22:33  18.220600 -63.068600
# 1   01-01-2021  United Kingdom  2021-01-02 05:22:33  32.307800 -64.750500
# 2   01-01-2021  United Kingdom  2021-01-02 05:22:33  18.420700 -64.640000
# 3   01-01-2021  United Kingdom  2021-01-02 05:22:33  19.313300 -81.254600
# 4   01-01-2021  United Kingdom  2021-01-02 05:22:33  49.372300  -2.364400
# 5   01-01-2021  United Kingdom  2021-01-02 05:22:33  52.355500  -1.174300
# 6   01-01-2021  United Kingdom  2021-01-02 05:22:33 -51.796300 -59.523600
# 7   01-01-2021  United Kingdom  2021-01-02 05:22:33  36.140800  -5.353600
# 8   01-01-2021  United Kingdom  2021-01-02 05:22:33  54.236100  -4.548100
# 9   01-01-2021  United Kingdom  2021-01-02 05:22:33  16.742498 -62.187366
# 10  01-01-2021  United Kingdom  2021-01-02 05:22:33  54.787700  -6.492300
# 11  01-01-2021  United Kingdom  2021-01-02 05:22:33  -7.946700 -14.355900
# 12  01-01-2021  United Kingdom  2021-01-02 05:22:33  56.490700  -4.202600
# 13  01-01-2021  United Kingdom  2021-01-02 05:22:33  21.694000 -71.797900
# 14  01-01-2021  United Kingdom  2021-01-02 05:22:33        NaN        NaN
# 15  01-01-2021  United Kingdom  2021-01-02 05:22:33  52.130700  -3.783700
# 16  01-01-2021  United Kingdom  2021-01-02 05:22:33  49.213800  -2.135800
# 17  01-01-2021  United Kingdom  2021-01-02 05:22:33  49.448196  -2.589490
#
#     Confirmed  Deaths  Recovered   Active  \
# 0          13       0         12        1
# 1         604      10        445      149
# 2          86       1         74       11
# 3         338       2        294       42
# 4           0       0       2445      554
# 5     2190702   64731          0  2125971
# 6          29       0         17       12
# 7        2212       7       1249      956
# 8         377      25        348        4
# 9          13       1         12        0
# 10      72834    1322          0    71512
# 11          4       0          3        1
# 12     129992    4578          0   125414
# 13        893       6        783      104
# 14          0       0          0        0
# 15     148537    3494          0   145043
# 16       2739      42          0        0
# 17        298      16          0        0
#
#                                          Combined_Key  Incident_Rate  \
# 0                            Anguilla, United Kingdom      86.655113
# 1                             Bermuda, United Kingdom     969.922759
# 2              British Virgin Islands, United Kingdom     284.419751
# 3                      Cayman Islands, United Kingdom     514.303104
# 4                     Channel Islands, United Kingdom    1794.145420
# 5                             England, United Kingdom    3913.561236
# 6         Falkland Islands (Malvinas), United Kingdom     832.615561
# 7                           Gibraltar, United Kingdom    6565.551631
# 8                         Isle of Man, United Kingdom     443.362499
# 9                          Montserrat, United Kingdom     260.052010
# 10                   Northern Ireland, United Kingdom    3870.854592
# 11  Saint Helena, Ascension and Tristan da Cunha, ...      70.658894
# 12                           Scotland, United Kingdom    2379.367781
# 13           Turks and Caicos Islands, United Kingdom    2306.420786
# 14                            Unknown, United Kingdom            NaN
# 15                              Wales, United Kingdom    4732.587778
# 16                             Jersey, United Kingdom       0.000000
# 17                           Guernsey, United Kingdom       0.000000
#
#     Case_Fatality_Ratio
# 0              0.000000
# 1              1.655629
# 2              1.162791
# 3              0.591716
# 4              1.961425
# 5              2.954806
# 6              0.000000
# 7              0.316456
# 8              6.631300
# 9              7.692308
# 10             1.815086
# 11             0.000000
# 12             3.521755
# 13             0.671892
# 14                  NaN
# 15             2.352276
# 16             0.000000
# 17             0.000000

# %%
# Get all daily data for India directly from github repo up to now
import pandas as pd 
Day='06-01-2022'
URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
DF_day=pd.read_csv(URL_Day)
DF_day['Day']=Day
cond=(DF_day.Country_Region=='United Kingdom')
Selec_columns=['Day','Country_Region', 'Last_Update',
       'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
       'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']
DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
DF_i
# Out:
#            Day  Country_Region          Last_Update        Lat      Long_  \
# 0   06-01-2022  United Kingdom  2022-06-02 05:20:39  18.220600 -63.068600
# 1   06-01-2022  United Kingdom  2022-06-02 05:20:39  32.307800 -64.750500
# 2   06-01-2022  United Kingdom  2022-06-02 05:20:39  18.420700 -64.640000
# 3   06-01-2022  United Kingdom  2022-06-02 05:20:39  19.313300 -81.254600
# 4   06-01-2022  United Kingdom  2022-06-02 05:20:39  49.372300  -2.364400
# 5   06-01-2022  United Kingdom  2022-06-02 05:20:39  52.355500  -1.174300
# 6   06-01-2022  United Kingdom  2022-06-02 05:20:39 -51.796300 -59.523600
# 7   06-01-2022  United Kingdom  2022-06-02 05:20:39  36.140800  -5.353600
# 8   06-01-2022  United Kingdom  2022-06-02 05:20:39  49.448196  -2.589490
# 9   06-01-2022  United Kingdom  2022-06-02 05:20:39  54.236100  -4.548100
# 10  06-01-2022  United Kingdom  2022-06-02 05:20:39  49.213800  -2.135800
# 11  06-01-2022  United Kingdom  2022-06-02 05:20:39  16.742498 -62.187366
# 12  06-01-2022  United Kingdom  2022-06-02 05:20:39  54.787700  -6.492300
# 13  06-01-2022  United Kingdom  2022-06-02 05:20:39  -7.946700 -14.355900
# 14  06-01-2022  United Kingdom  2022-06-02 05:20:39  56.490700  -4.202600
# 15  06-01-2022  United Kingdom  2022-06-02 05:20:39  21.694000 -71.797900
# 16  06-01-2022  United Kingdom  2022-06-02 05:20:39        NaN        NaN
# 17  06-01-2022  United Kingdom  2022-06-02 05:20:39  52.130700  -3.783700
#
#     Confirmed  Deaths  Recovered  Active  \
# 0        3294       9        NaN     NaN
# 1       15085     138        NaN     NaN
# 2        6765      62        NaN     NaN
# 3       25318      28        NaN     NaN
# 4           0       0        NaN     NaN
# 5    18762989  155470        NaN     NaN
# 6        1717       0        NaN     NaN
# 7       18419     102        NaN     NaN
# 8       25703      47        NaN     NaN
# 9       32966     106        NaN     NaN
# 10      50611     129        NaN     NaN
# 11        980       6        NaN     NaN
# 12     713294    3445        NaN     NaN
# 13          4       0        NaN     NaN
# 14    1955185   12361        NaN     NaN
# 15       6148      36        NaN     NaN
# 16          0       0        NaN     NaN
# 17     874425    7473        NaN     NaN
#
#                                          Combined_Key  Incident_Rate  \
# 0                            Anguilla, United Kingdom   21957.072390
# 1                             Bermuda, United Kingdom   24223.981501
# 2              British Virgin Islands, United Kingdom   22373.251315
# 3                      Cayman Islands, United Kingdom   38524.041388
# 4                     Channel Islands, United Kingdom       0.000000
# 5                             England, United Kingdom   33518.984515
# 6         Falkland Islands (Malvinas), United Kingdom   49296.583405
# 7                           Gibraltar, United Kingdom   54670.386750
# 8                            Guernsey, United Kingdom   40798.412698
# 9                         Isle of Man, United Kingdom   38768.934048
# 10                             Jersey, United Kingdom   46304.666057
# 11                         Montserrat, United Kingdom   19603.920784
# 12                   Northern Ireland, United Kingdom   37908.907313
# 13  Saint Helena, Ascension and Tristan da Cunha, ...      70.658894
# 14                           Scotland, United Kingdom   35787.619205
# 15           Turks and Caicos Islands, United Kingdom   15878.919366
# 16                            Unknown, United Kingdom            NaN
# 17                              Wales, United Kingdom   27860.351749
#
#     Case_Fatality_Ratio
# 0              0.273224
# 1              0.914816
# 2              0.916482
# 3              0.110593
# 4                   NaN
# 5              0.828599
# 6              0.000000
# 7              0.553776
# 8              0.182858
# 9              0.321543
# 10             0.254885
# 11             0.612245
# 12             0.482971
# 13             0.000000
# 14             0.632216
# 15             0.585556
# 16                  NaN
# 17             0.854619

# %%
List_of_days=[]
for year in range(2020,2022):
  for month in range(1,13):
    for day in range(1,32):
      month=int(month)
      if day <=9:
        day=f'0{day}'

      if month <= 9 :
        month=f'0{month}'
      List_of_days.append(f'{month}-{day}-{year}')

# %%
# Check this list 
List_of_days[0:10]
# Out:
# ['01-01-2020',
#  '01-02-2020',
#  '01-03-2020',
#  '01-04-2020',
#  '01-05-2020',
#  '01-06-2020',
#  '01-07-2020',
#  '01-08-2020',
#  '01-09-2020',
#  '01-10-2020']

# %%
Day='01-01-2021'

def Get_DF_i(Day):
    DF_i=None
    try: 
        URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
        DF_day=pd.read_csv(URL_Day)
        DF_day['Day']=Day
        cond=(DF_day.Country_Region=='United Kingdom')
        Selec_columns=['Day','Country_Region', 'Last_Update',
              'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
              'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']
        DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
    except:
    #print(f'{Day} is not available!')
        pass
    return DF_i

print(Get_DF_i(Day))

Day='02-31-2021'

print(Get_DF_i(Day))
# Out:
#            Day  Country_Region          Last_Update        Lat      Long_  \
# 0   01-01-2021  United Kingdom  2021-01-02 05:22:33  18.220600 -63.068600
# 1   01-01-2021  United Kingdom  2021-01-02 05:22:33  32.307800 -64.750500
# 2   01-01-2021  United Kingdom  2021-01-02 05:22:33  18.420700 -64.640000
# 3   01-01-2021  United Kingdom  2021-01-02 05:22:33  19.313300 -81.254600
# 4   01-01-2021  United Kingdom  2021-01-02 05:22:33  49.372300  -2.364400
# 5   01-01-2021  United Kingdom  2021-01-02 05:22:33  52.355500  -1.174300
# 6   01-01-2021  United Kingdom  2021-01-02 05:22:33 -51.796300 -59.523600
# 7   01-01-2021  United Kingdom  2021-01-02 05:22:33  36.140800  -5.353600
# 8   01-01-2021  United Kingdom  2021-01-02 05:22:33  54.236100  -4.548100
# 9   01-01-2021  United Kingdom  2021-01-02 05:22:33  16.742498 -62.187366
# 10  01-01-2021  United Kingdom  2021-01-02 05:22:33  54.787700  -6.492300
# 11  01-01-2021  United Kingdom  2021-01-02 05:22:33  -7.946700 -14.355900
# 12  01-01-2021  United Kingdom  2021-01-02 05:22:33  56.490700  -4.202600
# 13  01-01-2021  United Kingdom  2021-01-02 05:22:33  21.694000 -71.797900
# 14  01-01-2021  United Kingdom  2021-01-02 05:22:33        NaN        NaN
# 15  01-01-2021  United Kingdom  2021-01-02 05:22:33  52.130700  -3.783700
# 16  01-01-2021  United Kingdom  2021-01-02 05:22:33  49.213800  -2.135800
# 17  01-01-2021  United Kingdom  2021-01-02 05:22:33  49.448196  -2.589490
#
#     Confirmed  Deaths  Recovered   Active  \
# 0          13       0         12        1
# 1         604      10        445      149
# 2          86       1         74       11
# 3         338       2        294       42
# 4           0       0       2445      554
# 5     2190702   64731          0  2125971
# 6          29       0         17       12
# 7        2212       7       1249      956
# 8         377      25        348        4
# 9          13       1         12        0
# 10      72834    1322          0    71512
# 11          4       0          3        1
# 12     129992    4578          0   125414
# 13        893       6        783      104
# 14          0       0          0        0
# 15     148537    3494          0   145043
# 16       2739      42          0        0
# 17        298      16          0        0
#
#                                          Combined_Key  Incident_Rate  \
# 0                            Anguilla, United Kingdom      86.655113
# 1                             Bermuda, United Kingdom     969.922759
# 2              British Virgin Islands, United Kingdom     284.419751
# 3                      Cayman Islands, United Kingdom     514.303104
# 4                     Channel Islands, United Kingdom    1794.145420
# 5                             England, United Kingdom    3913.561236
# 6         Falkland Islands (Malvinas), United Kingdom     832.615561
# 7                           Gibraltar, United Kingdom    6565.551631
# 8                         Isle of Man, United Kingdom     443.362499
# 9                          Montserrat, United Kingdom     260.052010
# 10                   Northern Ireland, United Kingdom    3870.854592
# 11  Saint Helena, Ascension and Tristan da Cunha, ...      70.658894
# 12                           Scotland, United Kingdom    2379.367781
# 13           Turks and Caicos Islands, United Kingdom    2306.420786
# 14                            Unknown, United Kingdom            NaN
# 15                              Wales, United Kingdom    4732.587778
# 16                             Jersey, United Kingdom       0.000000
# 17                           Guernsey, United Kingdom       0.000000
#
#     Case_Fatality_Ratio
# 0              0.000000
# 1              1.655629
# 2              1.162791
# 3              0.591716
# 4              1.961425
# 5              2.954806
# 6              0.000000
# 7              0.316456
# 8              6.631300
# 9              7.692308
# 10             1.815086
# 11             0.000000
# 12             3.521755
# 13             0.671892
# 14                  NaN
# 15             2.352276
# 16             0.000000
# 17             0.000000
# None

# %%
import time 

Start=time.time()
DF_all=[]
for Day in List_of_days:
    DF_all.append(Get_DF_i(Day))
End=time.time()
Time_in_sec=round((End-Start)/60,2)
print(f'It took {Time_in_sec} minutes to get all data')
# Out:
# It took 4.04 minutes to get all data

# %%
DF_UK=pd.concat(DF_all).reset_index(drop=True)
# Create DateTime for Last_Update
DF_UK['Last_Updat']=pd.to_datetime(DF_UK.Last_Update, infer_datetime_format=True)  
DF_UK['Day']=pd.to_datetime(DF_UK.Day, infer_datetime_format=True)  

DF_UK['Case_Fatality_Ratio']=DF_UK['Case_Fatality_Ratio'].astype(float)

DF_UK.head(10)
# Out:
#          Day  Country_Region          Last_Update        Lat      Long_  \
# 0 2020-11-09  United Kingdom  2020-11-10 05:40:07  18.220600 -63.068600
# 1 2020-11-09  United Kingdom  2020-11-10 05:40:07  32.307800 -64.750500
# 2 2020-11-09  United Kingdom  2020-11-10 05:40:07  18.420700 -64.640000
# 3 2020-11-09  United Kingdom  2020-11-10 05:40:07  19.313300 -81.254600
# 4 2020-11-09  United Kingdom  2020-11-10 05:40:07  49.372300  -2.364400
# 5 2020-11-09  United Kingdom  2020-11-10 05:40:07  52.355500  -1.174300
# 6 2020-11-09  United Kingdom  2020-11-10 05:40:07 -51.796300 -59.523600
# 7 2020-11-09  United Kingdom  2020-11-10 05:40:07  36.140800  -5.353600
# 8 2020-11-09  United Kingdom  2020-11-10 05:40:07  54.236100  -4.548100
# 9 2020-11-09  United Kingdom  2020-11-10 05:40:07  16.742498 -62.187366
#
#    Confirmed  Deaths  Recovered    Active  \
# 0          3       0        3.0       0.0
# 1        214       9      182.0      23.0
# 2         71       1       70.0       0.0
# 3        250       1      236.0      13.0
# 4          0       0      766.0     137.0
# 5    1034708   43366        0.0  991342.0
# 6         13       0       13.0       0.0
# 7        805       0      692.0     113.0
# 8        357      25      329.0       3.0
# 9         13       1       12.0       0.0
#
#                                   Combined_Key  Incident_Rate  \
# 0                     Anguilla, United Kingdom      19.997334
# 1                      Bermuda, United Kingdom     343.648130
# 2       British Virgin Islands, United Kingdom     234.811655
# 3               Cayman Islands, United Kingdom     380.401704
# 4              Channel Islands, United Kingdom     557.774532
# 5                      England, United Kingdom    1848.445438
# 6  Falkland Islands (Malvinas), United Kingdom     373.241459
# 7                    Gibraltar, United Kingdom    2389.362144
# 8                  Isle of Man, United Kingdom     419.841942
# 9                   Montserrat, United Kingdom     260.052010
#
#    Case_Fatality_Ratio          Last_Updat
# 0             0.000000 2020-11-10 05:40:07
# 1             4.205607 2020-11-10 05:40:07
# 2             1.408451 2020-11-10 05:40:07
# 3             0.400000 2020-11-10 05:40:07
# 4             5.047319 2020-11-10 05:40:07
# 5             4.191134 2020-11-10 05:40:07
# 6             0.000000 2020-11-10 05:40:07
# 7             0.000000 2020-11-10 05:40:07
# 8             7.002801 2020-11-10 05:40:07
# 9             7.692308 2020-11-10 05:40:07

# %%
DF_UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7524 entries, 0 to 7523
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Day                  7524 non-null   datetime64[ns]
#  1   Country_Region       7524 non-null   object
#  2   Last_Update          7524 non-null   object
#  3   Lat                  7106 non-null   float64
#  4   Long_                7106 non-null   float64
#  5   Confirmed            7524 non-null   int64
#  6   Deaths               7524 non-null   int64
#  7   Recovered            5140 non-null   float64
#  8   Active               5140 non-null   float64
#  9   Combined_Key         7524 non-null   object
#  10  Incident_Rate        7106 non-null   float64
#  11  Case_Fatality_Ratio  7106 non-null   float64
#  12  Last_Updat           7524 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(2), object(3)
# memory usage: 764.3+ KB

# %%
import matplotlib.pyplot as plt 
import matplotlib
font = {'weight' : 'bold',
        'size'   : 18}

matplotlib.rc('font', **font)

plt.figure(figsize=(12,8))
DF_UK_u=DF_UK.copy()
DF_UK_u.index=DF_UK_u.Day
DF_UK_u['Case_Fatality_Ratio'].plot()
plt.ylabel('Case Fatality Ratio')
plt.grid()

# %%
plt.figure(figsize=(12,8))
DF_UK_u=DF_UK.copy()
DF_UK_u.index=DF_UK_u.Day
DF_UK_u['Confirmed'].plot()
plt.ylabel('Confirmed')
plt.grid()

# %%
plt.figure(figsize=(12,8))
DF_UK_u=DF_UK.copy()
DF_UK_u.index=DF_UK_u.Day
DF_UK_u['Active'].plot()
plt.ylabel('Active')
plt.grid()

# %%
'Confirmed','Deaths', 'Recovered', 'Active', 'Incident_Rate','Case_Fatality_Ratio'

# %%
Selec_Columns=['Confirmed','Deaths', 'Recovered', 'Active', 'Incident_Rate','Case_Fatality_Ratio']
DF_UK_u_2=DF_UK_u[Selec_Columns]

DF_UK_u_2

from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()


DF_UK_u_3 = pd.DataFrame(min_max_scaler.fit_transform(DF_UK_u_2[Selec_Columns]),columns=Selec_Columns)
DF_UK_u_3.index=DF_UK_u_2.index
DF_UK_u_3['Day']=DF_UK_u.Day
DF_UK_u_3.head(3)
# Out:
#                Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Day
# 2020-11-09  2.730040e-07  0.000000   0.000360  0.000000       0.000774
# 2020-11-09  1.947428e-05  0.000070   0.021870  0.000005       0.013306
# 2020-11-09  6.461094e-06  0.000008   0.008411  0.000000       0.009092
#
#             Case_Fatality_Ratio        Day
# Day
# 2020-11-09             0.000000 2020-11-09
# 2020-11-09             0.546729 2020-11-09
# 2020-11-09             0.183099 2020-11-09

# %%
DF_UK_u_3[Selec_Columns].plot(figsize=(20,10))
plt.savefig('output/UK_scoring_report.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-2768db333911> in <module>()
#       1 DF_UK_u_3[Selec_Columns].plot(figsize=(20,10))
# ----> 2 plt.savefig('output/UK_scoring_report.png')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/UK_scoring_report.png'

# %%
DF_UK_u_3.to_csv
# Out:
# <bound method NDFrame.to_csv of                Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Day
# 2020-11-09  2.730040e-07  0.000000   0.000360  0.000000       0.000774
# 2020-11-09  1.947428e-05  0.000070   0.021870  0.000005       0.013306
# 2020-11-09  6.461094e-06  0.000008   0.008411  0.000000       0.009092
# 2020-11-09  2.275033e-05  0.000008   0.028359  0.000003       0.014729
# 2020-11-09  0.000000e+00  0.000000   0.092045  0.000027       0.021597
# ...                  ...       ...        ...       ...            ...
# 2021-12-31  2.988484e-04  0.000201        NaN       NaN       0.328424
# 2021-12-31  0.000000e+00  0.000000        NaN       NaN            NaN
# 2021-12-31  5.752421e-02  0.050821        NaN       NaN       0.779851
# 2021-12-31  1.729207e-03  0.000689   0.000000  0.000000       0.000000
# 2021-12-31  7.099923e-04  0.000186   0.000000  0.000000       0.000000
#
#             Case_Fatality_Ratio        Day
# Day
# 2020-11-09             0.000000 2020-11-09
# 2020-11-09             0.546729 2020-11-09
# 2020-11-09             0.183099 2020-11-09
# 2020-11-09             0.052000 2020-11-09
# 2020-11-09             0.656151 2020-11-09
# ...                         ...        ...
# 2021-12-31             0.102923 2021-12-31
# 2021-12-31                  NaN 2021-12-31
# 2021-12-31             0.135054 2021-12-31
# 2021-12-31             0.000000 2021-12-31
# 2021-12-31             0.000000 2021-12-31
#
# [7524 rows x 7 columns]>

# %%
DF_UK_u_2.to_csv
# Out:
# <bound method NDFrame.to_csv of             Confirmed  Deaths  Recovered  Active  Incident_Rate  \
# Day
# 2020-11-09          3       0        3.0     0.0      19.997334
# 2020-11-09        214       9      182.0    23.0     343.648130
# 2020-11-09         71       1       70.0     0.0     234.811655
# 2020-11-09        250       1      236.0    13.0     380.401704
# 2020-11-09          0       0      766.0   137.0     557.774532
# ...               ...     ...        ...     ...            ...
# 2021-12-31       3284      26        NaN     NaN    8481.843070
# 2021-12-31          0       0        NaN     NaN            NaN
# 2021-12-31     632125    6567        NaN     NaN   20140.349200
# 2021-12-31      19002      89        0.0     0.0       0.000000
# 2021-12-31       7802      24        0.0     0.0       0.000000
#
#             Case_Fatality_Ratio
# Day
# 2020-11-09             0.000000
# 2020-11-09             4.205607
# 2020-11-09             1.408451
# 2020-11-09             0.400000
# 2020-11-09             5.047319
# ...                         ...
# 2021-12-31             0.791717
# 2021-12-31                  NaN
# 2021-12-31             1.038877
# 2021-12-31             0.000000
# 2021-12-31             0.000000
#
# [7524 rows x 6 columns]>

# %%
from sqlalchemy import create_engine
import psycopg2

host="postgres" # use "localhost" if you access from outside the localnet docker-compose env 
database="testDB"
user="me"
password="1234"
port='5432'
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
print(engine.table_names())
